# %%
# make sure jupyter path is correct for loading local moudules
import sys
# path to steric_simulator module relative to notebook
sys.path.append("../")
from energy_space_explorer import EnergyExplorer
from reaction_network import ReactionNetwork

# %%
base_input = '../input_files/snare2.pwr'
rn = ReactionNetwork(base_input, one_step=True)
rn.resolve_tree()
# Out:
# ['B']
# ['X']
# ['P']
# -----
# {'B'}
# {'B'}
# set()
# -----
# {'B'}
# {'X'}
# {'B'}
# False
# Allowed edges:
# ('P', 'X')
# Allowed edges:
# ('B', 'X')
# Connected Nodes:  ['B', 'X']
# Connected Edges:  [('B', 'X')]
# Allowed edges:
# ('B', 'P')
# New node added--1
# ['B', 'X']
# {('P', 'X'): [None, None, 1, tensor([-1300.], dtype=torch.float64)], ('B', 'X'): [None, None, 1, tensor([1660.], dtype=torch.float64)], ('B', 'P'): [None, None, 1, tensor([-4050.], dtype=torch.float64)]}
# New node added--2
# [0, 1, 2, 3]
# -----
# {'B'}
# {'P'}
# {'B'}
# False
# Allowed edges:
# ('P', 'X')
# Allowed edges:
# ('B', 'X')
# Allowed edges:
# ('B', 'P')
# Connected Nodes:  ['B', 'P']
# Connected Edges:  [('B', 'P')]
# New node added--1
# ['B', 'P']
# {('P', 'X'): [None, None, 1, tensor([-1300.], dtype=torch.float64)], ('B', 'X'): [None, None, 1, tensor([1660.], dtype=torch.float64)], ('B', 'P'): [None, None, 1, tensor([-4050.], dtype=torch.float64)]}
# New node added--2
# [0, 1, 2, 3, 4]
# Allowed edges:
# ('P', 'X')
# Allowed edges:
# ('B', 'X')
# Allowed edges:
# ('B', 'P')
# -----
# {'X'}
# {'B'}
# {'X'}
# False
# Allowed edges:
# ('P', 'X')
# Allowed edges:
# ('B', 'X')
# Connected Nodes:  ['X', 'B']
# Connected Edges:  [('X', 'B')]
# Allowed edges:
# ('B', 'P')
# -----
# {'X'}
# {'X'}
# set()
# -----
# {'X'}
# {'P'}
# {'X'}
# False
# Allowed edges:
# ('P', 'X')
# Connected Nodes:  ['X', 'P']
# Connected Edges:  [('X', 'P')]
# Allowed edges:
# ('B', 'X')
# Allowed edges:
# ('B', 'P')
# New node added--1
# ['X', 'P']
# {('P', 'X'): [None, None, 1, tensor([-1300.], dtype=torch.float64)], ('B', 'X'): [None, None, 1, tensor([1660.], dtype=torch.float64)], ('B', 'P'): [None, None, 1, tensor([-4050.], dtype=torch.float64)]}
# New node added--2
# [0, 1, 2, 3, 4, 5]
# -----
# {'X'}
# {'X', 'B'}
# set()
# -----
# {'X'}
# {'P', 'B'}
# {'X'}
# False
# Allowed edges:
# ('P', 'X')
# Connected Nodes:  ['X', 'B', 'P']
# Connected Edges:  [('X', 'P'), ('B', 'P')]
# Allowed edges:
# ('B', 'X')
# Connected Nodes:  ['X', 'B', 'P']
# Connected Edges:  [('X', 'P'), ('X', 'B'), ('B', 'P')]
# Allowed edges:
# ('B', 'P')
# New node added--1
# ['X', 'B', 'P']
# {('P', 'X'): [None, None, 1, tensor([-1300.], dtype=torch.float64)], ('B', 'X'): [None, None, 1, tensor([1660.], dtype=torch.float64)], ('B', 'P'): [None, None, 1, tensor([-4050.], dtype=torch.float64)]}
# New node added--2
# [0, 1, 2, 3, 4, 5, 6]
# Allowed edges:
# ('P', 'X')
# Allowed edges:
# ('B', 'X')
# Allowed edges:
# ('B', 'P')
# -----
# {'P'}
# {'B'}
# {'P'}
# False
# Allowed edges:
# ('P', 'X')
# Allowed edges:
# ('B', 'X')
# Allowed edges:
# ('B', 'P')
# Connected Nodes:  ['P', 'B']
# Connected Edges:  [('P', 'B')]
# -----
# {'P'}
# {'X'}
# {'P'}
# False
# Allowed edges:
# ('P', 'X')
# Connected Nodes:  ['P', 'X']
# Connected Edges:  [('P', 'X')]
# Allowed edges:
# ('B', 'X')
# Allowed edges:
# ('B', 'P')
# -----
# {'P'}
# {'P'}
# set()
# -----
# {'P'}
# {'X', 'B'}
# {'P'}
# False
# Allowed edges:
# ('P', 'X')
# Connected Nodes:  ['P', 'B', 'X']
# Connected Edges:  [('P', 'X'), ('B', 'X')]
# Allowed edges:
# ('B', 'X')
# Allowed edges:
# ('B', 'P')
# Connected Nodes:  ['P', 'B', 'X']
# Connected Edges:  [('P', 'X'), ('P', 'B'), ('B', 'X')]
# {('P', 'X'): [None, None, 1, tensor([-1300.], dtype=torch.float64)], ('B', 'X'): [None, None, 1, tensor([1660.], dtype=torch.float64)], ('B', 'P'): [None, None, 1, tensor([-4050.], dtype=torch.float64)]}
# -----
# {'P'}
# {'P', 'B'}
# set()
# -----
# {'P'}
# {'P', 'X'}
# set()
# -----
# {'P'}
# {'P', 'X', 'B'}
# set()
# Allowed edges:
# ('P', 'X')
# Allowed edges:
# ('B', 'X')
# Allowed edges:
# ('B', 'P')
# -----
# {'X', 'B'}
# {'B'}
# {'X'}
# -----
# {'X', 'B'}
# {'X'}
# {'B'}
# -----
# {'X', 'B'}
# {'P'}
# {'X', 'B'}
# False
# Allowed edges:
# ('P', 'X')
# Connected Nodes:  ['B', 'X', 'P']
# Connected Edges:  [('B', 'X'), ('X', 'P')]
# Allowed edges:
# ('B', 'X')
# Allowed edges:
# ('B', 'P')
# Connected Nodes:  ['B', 'X', 'P']
# Connected Edges:  [('B', 'X'), ('B', 'P'), ('X', 'P')]
# -----
# {'X', 'B'}
# {'X', 'B'}
# set()
# -----
# {'X', 'B'}
# {'P', 'B'}
# {'X'}
# -----
# {'X', 'B'}
# {'P', 'X'}
# {'B'}
# -----
# {'X', 'B'}
# {'P', 'X', 'B'}
# set()
# Allowed edges:
# ('P', 'X')
# Allowed edges:
# ('B', 'X')
# Allowed edges:
# ('B', 'P')
# -----
# {'P', 'B'}
# {'B'}
# {'P'}
# -----
# {'P', 'B'}
# {'X'}
# {'P', 'B'}
# False
# Allowed edges:
# ('P', 'X')
# Connected Nodes:  ['B', 'P', 'X']
# Connected Edges:  [('B', 'P'), ('P', 'X')]
# Allowed edges:
# ('B', 'X')
# Connected Nodes:  ['B', 'P', 'X']
# Connected Edges:  [('B', 'P'), ('B', 'X'), ('P', 'X')]
# Allowed edges:
# ('B', 'P')
# -----
# {'P', 'B'}
# {'P'}
# {'B'}
# -----
# {'P', 'B'}
# {'X', 'B'}
# {'P'}
# -----
# {'P', 'B'}
# {'P', 'B'}
# set()
# -----
# {'P', 'B'}
# {'P', 'X'}
# {'B'}
# -----
# {'P', 'B'}
# {'P', 'X', 'B'}
# set()
# Allowed edges:
# ('P', 'X')
# Allowed edges:
# ('B', 'X')
# Allowed edges:
# ('B', 'P')
# -----
# {'P', 'X'}
# {'B'}
# {'P', 'X'}
# False
# Allowed edges:
# ('P', 'X')
# Allowed edges:
# ('B', 'X')
# Connected Nodes:  ['X', 'P', 'B']
# Connected Edges:  [('X', 'P'), ('X', 'B')]
# Allowed edges:
# ('B', 'P')
# Connected Nodes:  ['X', 'P', 'B']
# Connected Edges:  [('X', 'P'), ('X', 'B'), ('P', 'B')]
# {('P', 'X'): [None, None, 1, tensor([-1300.], dtype=torch.float64)], ('B', 'X'): [None, None, 1, tensor([1660.], dtype=torch.float64)], ('B', 'P'): [None, None, 1, tensor([-4050.], dtype=torch.float64)]}
# -----
# {'P', 'X'}
# {'X'}
# {'P'}
# -----
# {'P', 'X'}
# {'P'}
# {'X'}
# -----
# {'P', 'X'}
# {'X', 'B'}
# {'P'}
# -----
# {'P', 'X'}
# {'P', 'B'}
# {'X'}
# -----
# {'P', 'X'}
# {'P', 'X'}
# set()
# -----
# {'P', 'X'}
# {'P', 'X', 'B'}
# set()
# Allowed edges:
# ('P', 'X')
# Allowed edges:
# ('B', 'X')
# Allowed edges:
# ('B', 'P')
# -----
# {'P', 'X', 'B'}
# {'B'}
# {'P', 'X'}
# -----
# {'P', 'X', 'B'}
# {'X'}
# {'P', 'B'}
# -----
# {'P', 'X', 'B'}
# {'P'}
# {'X', 'B'}
# -----
# {'P', 'X', 'B'}
# {'X', 'B'}
# {'P'}
# -----
# {'P', 'X', 'B'}
# {'P', 'B'}
# {'X'}
# -----
# {'P', 'X', 'B'}
# {'P', 'X'}
# {'B'}
# -----
# {'P', 'X', 'B'}
# {'P', 'X', 'B'}
# set()
# Allowed edges:
# ('P', 'X')
# Allowed edges:
# ('B', 'X')
# Allowed edges:
# ('B', 'P')

# %%
en = EnergyExplorer(rn, subunit_dir='../pdbs/snare_subunits/')
en.explore_network()
# Out:
# PyRosetta-4 2021 [Rosetta PyRosetta4.Release.python37.ubuntu 2021.30+release.101ad938a08a051669a68dbe2bb6ff4538172577 2021-07-29T16:51:29] retrieved from: http://www.pyrosetta.org
# (C) Copyright Rosetta Commons Member Institutions. Created in JHU by Sergey Lyskov and PyRosetta Team.
# core.init: Checking for fconfig files in pwd and ./rosetta/flags
# core.init: Rosetta version: PyRosetta4.Release.python37.ubuntu r291 2021.30+release.101ad938a08 101ad938a08a051669a68dbe2bb6ff4538172577 http://www.pyrosetta.org 2021-07-29T16:51:29
# core.init: command: PyRosetta -ex1 -ex2aro -database /home/adip/software/anaconda3/envs/steric_free_sim/lib/python3.7/site-packages/pyrosetta-2021.30+release.101ad938a08-py3.7-linux-x86_64.egg/pyrosetta/database
# basic.random.init_random_generator: 'RNG device' seed mode, using '/dev/urandom', seed=-837549821 seed_offset=0 real_seed=-837549821
# basic.random.init_random_generator: RandomGenerator:init: Normal mode, seed=-837549821 RG_type=mt19937
# core.scoring.ScoreFunctionFactory: SCOREFUNCTION: ref2015
# core.scoring.etable: Starting energy table calculation
# core.scoring.etable: smooth_etable: changing atr/rep split to bottom of energy well
# core.scoring.etable: smooth_etable: spline smoothing lj etables (maxdis = 6)
# core.scoring.etable: smooth_etable: spline smoothing solvation etables (max_dis = 6)
# core.scoring.etable: Finished calculating energy tables.
# basic.io.database: Database file opened: scoring/score_functions/hbonds/ref2015_params/HBPoly1D.csv
# basic.io.database: Database file opened: scoring/score_functions/hbonds/ref2015_params/HBFadeIntervals.csv
# basic.io.database: Database file opened: scoring/score_functions/hbonds/ref2015_params/HBEval.csv
# basic.io.database: Database file opened: scoring/score_functions/hbonds/ref2015_params/DonStrength.csv
# basic.io.database: Database file opened: scoring/score_functions/hbonds/ref2015_params/AccStrength.csv
# core.chemical.GlobalResidueTypeSet: Finished initializing fa_standard residue type set.  Created 983 residue types
# core.chemical.GlobalResidueTypeSet: Total time to initialize 0.72721 seconds.
# basic.io.database: Database file opened: scoring/score_functions/rama/fd/all.ramaProb
# basic.io.database: Database file opened: scoring/score_functions/rama/fd/prepro.ramaProb
# basic.io.database: Database file opened: scoring/score_functions/omega/omega_ppdep.all.txt
# basic.io.database: Database file opened: scoring/score_functions/omega/omega_ppdep.gly.txt
# basic.io.database: Database file opened: scoring/score_functions/omega/omega_ppdep.pro.txt
# basic.io.database: Database file opened: scoring/score_functions/omega/omega_ppdep.valile.txt
# basic.io.database: Database file opened: scoring/score_functions/P_AA_pp/P_AA
# basic.io.database: Database file opened: scoring/score_functions/P_AA_pp/P_AA_n
# core.scoring.P_AA: shapovalov_lib::shap_p_aa_pp_smooth_level of 1( aka low_smooth ) got activated.
# basic.io.database: Database file opened: scoring/score_functions/P_AA_pp/shapovalov/10deg/kappa131/a20.prop
# protocols.relax.RelaxScriptManager: Reading relax scripts list from database.
# core.scoring.ScoreFunctionFactory: SCOREFUNCTION: ref2015
# protocols.relax.RelaxScriptManager: Looking for MonomerRelax2019.txt
# protocols.relax.RelaxScriptManager: ================== Reading script file: /home/adip/software/anaconda3/envs/steric_free_sim/lib/python3.7/site-packages/pyrosetta-2021.30+release.101ad938a08-py3.7-linux-x86_64.egg/pyrosetta/database/sampling/relax_scripts/MonomerRelax2019.txt ==================
# protocols.relax.RelaxScriptManager: repeat %%nrepeats%%
# protocols.relax.RelaxScriptManager: coord_cst_weight 1.0
# protocols.relax.RelaxScriptManager: scale:fa_rep 0.040
# protocols.relax.RelaxScriptManager: repack
# protocols.relax.RelaxScriptManager: scale:fa_rep 0.051
# protocols.relax.RelaxScriptManager: min 0.01
# protocols.relax.RelaxScriptManager: coord_cst_weight 0.5
# protocols.relax.RelaxScriptManager: scale:fa_rep 0.265
# protocols.relax.RelaxScriptManager: repack
# protocols.relax.RelaxScriptManager: scale:fa_rep 0.280
# protocols.relax.RelaxScriptManager: min 0.01
# protocols.relax.RelaxScriptManager: coord_cst_weight 0.0
# protocols.relax.RelaxScriptManager: scale:fa_rep 0.559
# protocols.relax.RelaxScriptManager: repack
# protocols.relax.RelaxScriptManager: scale:fa_rep 0.581
# protocols.relax.RelaxScriptManager: min 0.01
# protocols.relax.RelaxScriptManager: coord_cst_weight 0.0
# protocols.relax.RelaxScriptManager: scale:fa_rep 1
# protocols.relax.RelaxScriptManager: repack
# protocols.relax.RelaxScriptManager: min 0.00001
# protocols.relax.RelaxScriptManager: accept_to_best
# protocols.relax.RelaxScriptManager: endrepeat
# Lacking serializable rosetta build. Parallel processing disabled. Recommend compiling from source with --serialization flag
#  Continuing to process sequentially <ipykernel.iostream.OutStream object at 0x7f7e4508de80>
# pdb_file:  /home/adip/multi_assembly/multi_assembly/steric_free_simulator/pdbs/snare_subunits/B.clean.pdb
# core.import_pose.import_pose: File '/home/adip/multi_assembly/multi_assembly/steric_free_simulator/pdbs/snare_subunits/B.clean.pdb' automatically determined to be of type PDB
# core.conformation.Conformation: [ WARNING ] missing heavyatom:  OXT on residue LEU:CtermProteinFull 69
# basic.io.database: Database file opened: scoring/score_functions/elec_cp_reps.dat
# core.scoring.elec.util: Read 40 countpair representative atoms
# core.pack.dunbrack.RotamerLibrary: shapovalov_lib_fixes_enable option is true.
# core.pack.dunbrack.RotamerLibrary: shapovalov_lib::shap_dun10_smooth_level of 1( aka lowest_smooth ) got activated.
# core.pack.dunbrack.RotamerLibrary: Binary rotamer library selected: /home/adip/software/anaconda3/envs/steric_free_sim/lib/python3.7/site-packages/pyrosetta-2021.30+release.101ad938a08-py3.7-linux-x86_64.egg/pyrosetta/database/rotamer/shapovalov/StpDwn_0-0-0/Dunbrack10.lib.bin
# core.pack.dunbrack.RotamerLibrary: Using Dunbrack library binary file '/home/adip/software/anaconda3/envs/steric_free_sim/lib/python3.7/site-packages/pyrosetta-2021.30+release.101ad938a08-py3.7-linux-x86_64.egg/pyrosetta/database/rotamer/shapovalov/StpDwn_0-0-0/Dunbrack10.lib.bin'.
# core.pack.dunbrack.RotamerLibrary: Dunbrack 2010 library took 0.170752 seconds to load from binary
# protocols.relax.FastRelax: CMD: repeat  210.904  0  0  0.55
# protocols.relax.FastRelax: CMD: coord_cst_weight  210.904  0  0  0.55
# protocols.relax.FastRelax: CMD: scale:fa_rep  115.67  0  0  0.022
# core.pack.task: Packer task: initialize from command line()
# core.pack.pack_rotamers: built 1151 rotamers at 69 positions.
# core.pack.interaction_graph.interaction_graph_factory: Instantiating DensePDInteractionGraph
# protocols.relax.FastRelax: CMD: repack  -96.7134  0  0  0.022
# protocols.relax.FastRelax: CMD: scale:fa_rep  -93.6276  0  0  0.02805
# protocols.relax.FastRelax: CMD: min  -93.7238  0.00627265  0.00627265  0.02805
# protocols.relax.FastRelax: CMD: coord_cst_weight  -93.7238  0.00627265  0.00627265  0.02805
# protocols.relax.FastRelax: CMD: scale:fa_rep  -33.8411  0.00627265  0.00627265  0.14575
# core.pack.task: Packer task: initialize from command line()
# core.pack.pack_rotamers: built 1108 rotamers at 69 positions.
# core.pack.interaction_graph.interaction_graph_factory: Instantiating DensePDInteractionGraph
# protocols.relax.FastRelax: CMD: repack  -59.1773  0.00627265  0.00627265  0.14575
# protocols.relax.FastRelax: CMD: scale:fa_rep  -57.2189  0.00627265  0.00627265  0.154
# protocols.relax.FastRelax: CMD: min  -146.649  3.73493  3.73493  0.154
# protocols.relax.FastRelax: CMD: coord_cst_weight  -146.649  3.73493  3.73493  0.154
# protocols.relax.FastRelax: CMD: scale:fa_rep  -132.851  3.73493  3.73493  0.30745
# core.pack.task: Packer task: initialize from command line()
# core.pack.pack_rotamers: built 990 rotamers at 69 positions.
# core.pack.interaction_graph.interaction_graph_factory: Instantiating DensePDInteractionGraph
# protocols.relax.FastRelax: CMD: repack  -133.936  3.73493  3.73493  0.30745
# protocols.relax.FastRelax: CMD: scale:fa_rep  -132.869  3.73493  3.73493  0.31955
# protocols.relax.FastRelax: CMD: min  -132.897  3.73707  3.73707  0.31955
# protocols.relax.FastRelax: CMD: coord_cst_weight  -132.897  3.73707  3.73707  0.31955
# protocols.relax.FastRelax: CMD: scale:fa_rep  -112.614  3.73707  3.73707  0.55
# core.pack.task: Packer task: initialize from command line()
# core.pack.pack_rotamers: built 986 rotamers at 69 positions.
# core.pack.interaction_graph.interaction_graph_factory: Instantiating DensePDInteractionGraph
# protocols.relax.FastRelax: CMD: repack  -113.058  3.73707  3.73707  0.55
# protocols.relax.FastRelax: CMD: min  -139.215  4.49212  4.49212  0.55
# protocols.relax.FastRelax: MRP: 0  -139.215  -139.215  4.49212  4.49212
# protocols.relax.FastRelax: CMD: accept_to_best  -139.215  4.49212  4.49212  0.55
# protocols.relax.FastRelax: CMD: endrepeat  -139.215  4.49212  4.49212  0.55
# protocols.relax.FastRelax: CMD: coord_cst_weight  -139.215  4.49212  4.49212  0.55
# protocols.relax.FastRelax: CMD: scale:fa_rep  -166.733  4.49212  4.49212  0.022
# core.pack.task: Packer task: initialize from command line()
# core.pack.pack_rotamers: built 1014 rotamers at 69 positions.
# core.pack.interaction_graph.interaction_graph_factory: Instantiating DensePDInteractionGraph
# protocols.relax.FastRelax: CMD: repack  -172.783  4.49212  4.49212  0.022
# protocols.relax.FastRelax: CMD: scale:fa_rep  -171.583  4.49212  4.49212  0.02805
# protocols.relax.FastRelax: CMD: min  -171.61  4.48987  4.48987  0.02805
# protocols.relax.FastRelax: CMD: coord_cst_weight  -171.61  4.48987  4.48987  0.02805
# protocols.relax.FastRelax: CMD: scale:fa_rep  -148.298  4.48987  4.48987  0.14575
# core.pack.task: Packer task: initialize from command line()
# core.pack.pack_rotamers: built 1006 rotamers at 69 positions.
# core.pack.interaction_graph.interaction_graph_factory: Instantiating DensePDInteractionGraph
# protocols.relax.FastRelax: CMD: repack  -161.977  4.48987  4.48987  0.14575
# protocols.relax.FastRelax: CMD: scale:fa_rep  -161.409  4.48987  4.48987  0.154
# protocols.relax.FastRelax: CMD: min  -161.423  4.48851  4.48851  0.154
# protocols.relax.FastRelax: CMD: coord_cst_weight  -161.423  4.48851  4.48851  0.154
# protocols.relax.FastRelax: CMD: scale:fa_rep  -150.859  4.48851  4.48851  0.30745
# core.pack.task: Packer task: initialize from command line()
# core.pack.pack_rotamers: built 1000 rotamers at 69 positions.
# core.pack.interaction_graph.interaction_graph_factory: Instantiating DensePDInteractionGraph
# protocols.relax.FastRelax: CMD: repack  -151.211  4.48851  4.48851  0.30745
# protocols.relax.FastRelax: CMD: scale:fa_rep  -150.483  4.48851  4.48851  0.31955
# protocols.relax.FastRelax: CMD: min  -150.499  4.4865  4.4865  0.31955
# protocols.relax.FastRelax: CMD: coord_cst_weight  -150.499  4.4865  4.4865  0.31955
# protocols.relax.FastRelax: CMD: scale:fa_rep  -136.638  4.4865  4.4865  0.55
# core.pack.task: Packer task: initialize from command line()
# core.pack.pack_rotamers: built 992 rotamers at 69 positions.
# core.pack.interaction_graph.interaction_graph_factory: Instantiating DensePDInteractionGraph
# protocols.relax.FastRelax: CMD: repack  -136.754  4.4865  4.4865  0.55
# protocols.relax.FastRelax: CMD: min  -140.337  4.43218  4.43218  0.55
# protocols.relax.FastRelax: MRP: 1  -140.337  -140.337  4.43218  4.43218
# protocols.relax.FastRelax: CMD: accept_to_best  -140.337  4.43218  4.43218  0.55
# protocols.relax.FastRelax: CMD: endrepeat  -140.337  4.43218  4.43218  0.55
# protocols.relax.FastRelax: CMD: coord_cst_weight  -140.337  4.43218  4.43218  0.55
# protocols.relax.FastRelax: CMD: scale:fa_rep  -167.771  4.43218  4.43218  0.022
# core.pack.task: Packer task: initialize from command line()
# core.pack.pack_rotamers: built 1014 rotamers at 69 positions.
# core.pack.interaction_graph.interaction_graph_factory: Instantiating DensePDInteractionGraph
# protocols.relax.FastRelax: CMD: repack  -172.89  4.43218  4.43218  0.022
# protocols.relax.FastRelax: CMD: scale:fa_rep  -171.67  4.43218  4.43218  0.02805
# protocols.relax.FastRelax: CMD: min  -171.699  4.4299  4.4299  0.02805
# protocols.relax.FastRelax: CMD: coord_cst_weight  -171.699  4.4299  4.4299  0.02805
# protocols.relax.FastRelax: CMD: scale:fa_rep  -148.019  4.4299  4.4299  0.14575
# core.pack.task: Packer task: initialize from command line()
# core.pack.pack_rotamers: built 1006 rotamers at 69 positions.
# core.pack.interaction_graph.interaction_graph_factory: Instantiating DensePDInteractionGraph
# protocols.relax.FastRelax: CMD: repack  -162.249  4.4299  4.4299  0.14575
# protocols.relax.FastRelax: CMD: scale:fa_rep  -161.684  4.4299  4.4299  0.154
# protocols.relax.FastRelax: CMD: min  -161.699  4.42858  4.42858  0.154
# protocols.relax.FastRelax: CMD: coord_cst_weight  -161.699  4.42858  4.42858  0.154
# protocols.relax.FastRelax: CMD: scale:fa_rep  -151.198  4.42858  4.42858  0.30745
# core.pack.task: Packer task: initialize from command line()
# core.pack.pack_rotamers: built 1000 rotamers at 69 positions.
# core.pack.interaction_graph.interaction_graph_factory: Instantiating DensePDInteractionGraph
# protocols.relax.FastRelax: CMD: repack  -151.545  4.42858  4.42858  0.30745
# protocols.relax.FastRelax: CMD: scale:fa_rep  -150.82  4.42858  4.42858  0.31955
# protocols.relax.FastRelax: CMD: min  -150.836  4.42666  4.42666  0.31955
# protocols.relax.FastRelax: CMD: coord_cst_weight  -150.836  4.42666  4.42666  0.31955
# protocols.relax.FastRelax: CMD: scale:fa_rep  -137.035  4.42666  4.42666  0.55
# core.pack.task: Packer task: initialize from command line()
# core.pack.pack_rotamers: built 991 rotamers at 69 positions.
# core.pack.interaction_graph.interaction_graph_factory: Instantiating DensePDInteractionGraph
# protocols.relax.FastRelax: CMD: repack  -137.146  4.42666  4.42666  0.55
# protocols.relax.FastRelax: CMD: min  -140.342  4.43931  4.43931  0.55
# protocols.relax.FastRelax: MRP: 2  -140.342  -140.342  4.43931  4.43931
# protocols.relax.FastRelax: CMD: accept_to_best  -140.342  4.43931  4.43931  0.55
# protocols.relax.FastRelax: CMD: endrepeat  -140.342  4.43931  4.43931  0.55
# protocols.relax.FastRelax: CMD: coord_cst_weight  -140.342  4.43931  4.43931  0.55
# protocols.relax.FastRelax: CMD: scale:fa_rep  -167.766  4.43931  4.43931  0.022
# core.pack.task: Packer task: initialize from command line()
# core.pack.pack_rotamers: built 1013 rotamers at 69 positions.
# core.pack.interaction_graph.interaction_graph_factory: Instantiating DensePDInteractionGraph
# protocols.relax.FastRelax: CMD: repack  -172.969  4.43931  4.43931  0.022
# protocols.relax.FastRelax: CMD: scale:fa_rep  -171.765  4.43931  4.43931  0.02805
# protocols.relax.FastRelax: CMD: min  -171.793  4.43708  4.43708  0.02805
# protocols.relax.FastRelax: CMD: coord_cst_weight  -171.793  4.43708  4.43708  0.02805
# protocols.relax.FastRelax: CMD: scale:fa_rep  -148.42  4.43708  4.43708  0.14575
# core.pack.task: Packer task: initialize from command line()
# core.pack.pack_rotamers: built 1005 rotamers at 69 positions.
# core.pack.interaction_graph.interaction_graph_factory: Instantiating DensePDInteractionGraph
# protocols.relax.FastRelax: CMD: repack  -162.267  4.43708  4.43708  0.14575
# protocols.relax.FastRelax: CMD: scale:fa_rep  -161.704  4.43708  4.43708  0.154
# protocols.relax.FastRelax: CMD: min  -161.719  4.43577  4.43577  0.154
# protocols.relax.FastRelax: CMD: coord_cst_weight  -161.719  4.43577  4.43577  0.154
# protocols.relax.FastRelax: CMD: scale:fa_rep  -151.249  4.43577  4.43577  0.30745
# core.pack.task: Packer task: initialize from command line()
# core.pack.pack_rotamers: built 999 rotamers at 69 positions.
# core.pack.interaction_graph.interaction_graph_factory: Instantiating DensePDInteractionGraph
# protocols.relax.FastRelax: CMD: repack  -151.249  4.43577  4.43577  0.30745
# protocols.relax.FastRelax: CMD: scale:fa_rep  -150.423  4.43577  4.43577  0.31955
# protocols.relax.FastRelax: CMD: min  -150.456  4.43401  4.43401  0.31955
# protocols.relax.FastRelax: CMD: coord_cst_weight  -150.456  4.43401  4.43401  0.31955
# protocols.relax.FastRelax: CMD: scale:fa_rep  -134.757  4.43401  4.43401  0.55
# core.pack.task: Packer task: initialize from command line()
# core.pack.pack_rotamers: built 989 rotamers at 69 positions.
# core.pack.interaction_graph.interaction_graph_factory: Instantiating DensePDInteractionGraph
# protocols.relax.FastRelax: CMD: repack  -137.163  4.43401  4.43401  0.55
# protocols.relax.FastRelax: CMD: min  -140.343  4.43334  4.43334  0.55
# protocols.relax.FastRelax: MRP: 3  -140.343  -140.343  4.43334  4.43334
# protocols.relax.FastRelax: CMD: accept_to_best  -140.343  4.43334  4.43334  0.55
# protocols.relax.FastRelax: CMD: endrepeat  -140.343  4.43334  4.43334  0.55
# protocols.relax.FastRelax: CMD: coord_cst_weight  -140.343  4.43334  4.43334  0.55
# protocols.relax.FastRelax: CMD: scale:fa_rep  -167.788  4.43334  4.43334  0.022
# core.pack.task: Packer task: initialize from command line()
# core.pack.pack_rotamers: built 1013 rotamers at 69 positions.
# core.pack.interaction_graph.interaction_graph_factory: Instantiating DensePDInteractionGraph
# protocols.relax.FastRelax: CMD: repack  -172.987  4.43334  4.43334  0.022
# protocols.relax.FastRelax: CMD: scale:fa_rep  -171.788  4.43334  4.43334  0.02805
# protocols.relax.FastRelax: CMD: min  -171.816  4.4311  4.4311  0.02805
# protocols.relax.FastRelax: CMD: coord_cst_weight  -171.816  4.4311  4.4311  0.02805
# protocols.relax.FastRelax: CMD: scale:fa_rep  -148.532  4.4311  4.4311  0.14575
# core.pack.task: Packer task: initialize from command line()
# core.pack.pack_rotamers: built 1005 rotamers at 69 positions.
# core.pack.interaction_graph.interaction_graph_factory: Instantiating DensePDInteractionGraph
# protocols.relax.FastRelax: CMD: repack  -162.272  4.4311  4.4311  0.14575
# protocols.relax.FastRelax: CMD: scale:fa_rep  -161.709  4.4311  4.4311  0.154
# protocols.relax.FastRelax: CMD: min  -161.723  4.42979  4.42979  0.154
# protocols.relax.FastRelax: CMD: coord_cst_weight  -161.723  4.42979  4.42979  0.154
# protocols.relax.FastRelax: CMD: scale:fa_rep  -151.256  4.42979  4.42979  0.30745
# core.pack.task: Packer task: initialize from command line()
# core.pack.pack_rotamers: built 999 rotamers at 69 positions.
# core.pack.interaction_graph.interaction_graph_factory: Instantiating DensePDInteractionGraph
# protocols.relax.FastRelax: CMD: repack  -151.552  4.42979  4.42979  0.30745
# protocols.relax.FastRelax: CMD: scale:fa_rep  -150.827  4.42979  4.42979  0.31955
# protocols.relax.FastRelax: CMD: min  -150.843  4.42788  4.42788  0.31955
# protocols.relax.FastRelax: CMD: coord_cst_weight  -150.843  4.42788  4.42788  0.31955
# protocols.relax.FastRelax: CMD: scale:fa_rep  -137.05  4.42788  4.42788  0.55
# core.pack.task: Packer task: initialize from command line()
# core.pack.pack_rotamers: built 991 rotamers at 69 positions.
# core.pack.interaction_graph.interaction_graph_factory: Instantiating DensePDInteractionGraph
# protocols.relax.FastRelax: CMD: repack  -137.159  4.42788  4.42788  0.55
# protocols.relax.FastRelax: CMD: min  -140.341  4.42537  4.42537  0.55
# protocols.relax.FastRelax: MRP: 4  -140.341  -140.343  4.43334  4.43334
# protocols.relax.FastRelax: CMD: accept_to_best  -140.341  4.42537  4.42537  0.55
# protocols.relax.FastRelax: CMD: endrepeat  -140.341  4.42537  4.42537  0.55
# protocols::checkpoint: Deleting checkpoints of FastRelax
# core.scoring.ScoreFunctionFactory: SCOREFUNCTION: ref2015
# pdb_file:  /home/adip/multi_assembly/multi_assembly/steric_free_simulator/pdbs/snare_subunits/.~lock.N.clean.pdb
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~/multi_assembly/multi_assembly/steric_free_simulator/energy_space_explorer.py in __init__(self, net, subunit_dir)
#      56             with Pool(len(subunit_files)) as p:
# ---> 57                 results = p.map(self._pose_from_pdb, subunit_files)
#      58         except Exception:
#
# ~/software/anaconda3/envs/steric_free_sim/lib/python3.7/site-packages/pathos/multiprocessing.py in map(self, f, *args, **kwds)
#     138         _pool = self._serve()
# --> 139         return _pool.map(star(f), zip(*args)) # chunksize
#     140     map.__doc__ = AbstractWorkerPool.map.__doc__
#
# ~/software/anaconda3/envs/steric_free_sim/lib/python3.7/site-packages/multiprocess/pool.py in map(self, func, iterable, chunksize)
#     267         '''
# --> 268         return self._map_async(func, iterable, mapstar, chunksize).get()
#     269
#
# ~/software/anaconda3/envs/steric_free_sim/lib/python3.7/site-packages/multiprocess/pool.py in get(self, timeout)
#     656         else:
# --> 657             raise self._value
#     658
#
# ~/software/anaconda3/envs/steric_free_sim/lib/python3.7/site-packages/multiprocess/pool.py in _handle_tasks(taskqueue, put, outqueue, pool, cache)
#     430                     try:
# --> 431                         put(task)
#     432                     except Exception as e:
#
# ~/software/anaconda3/envs/steric_free_sim/lib/python3.7/site-packages/multiprocess/connection.py in send(self, obj)
#     208         self._check_writable()
# --> 209         self._send_bytes(_ForkingPickler.dumps(obj))
#     210
#
# ~/software/anaconda3/envs/steric_free_sim/lib/python3.7/site-packages/multiprocess/reduction.py in dumps(cls, obj, protocol, *args, **kwds)
#      53         buf = io.BytesIO()
# ---> 54         cls(buf, protocol, *args, **kwds).dump(obj)
#      55         return buf.getbuffer()
#
# ~/software/anaconda3/envs/steric_free_sim/lib/python3.7/site-packages/dill/_dill.py in dump(self, obj)
#     497         else:
# --> 498             StockPickler.dump(self, obj)
#     499         stack.clear()  # clear record of 'recursion-sensitive' pickled objects
#
# ~/software/anaconda3/envs/steric_free_sim/lib/python3.7/pickle.py in dump(self, obj)
#     436             self.framer.start_framing()
# --> 437         self.save(obj)
#     438         self.write(STOP)
#
# ~/software/anaconda3/envs/steric_free_sim/lib/python3.7/pickle.py in save(self, obj, save_persistent_id)
#     503         if f is not None:
# --> 504             f(self, obj) # Call unbound method with explicit self
#     505             return
#
# ~/software/anaconda3/envs/steric_free_sim/lib/python3.7/pickle.py in save_tuple(self, obj)
#     785         for element in obj:
# --> 786             save(element)
#     787
#
# ~/software/anaconda3/envs/steric_free_sim/lib/python3.7/pickle.py in save(self, obj, save_persistent_id)
#     503         if f is not None:
# --> 504             f(self, obj) # Call unbound method with explicit self
#     505             return
#
# ~/software/anaconda3/envs/steric_free_sim/lib/python3.7/pickle.py in save_tuple(self, obj)
#     770             for element in obj:
# --> 771                 save(element)
#     772             # Subtle.  Same as in the big comment below.
#
# ~/software/anaconda3/envs/steric_free_sim/lib/python3.7/pickle.py in save(self, obj, save_persistent_id)
#     503         if f is not None:
# --> 504             f(self, obj) # Call unbound method with explicit self
#     505             return
#
# ~/software/anaconda3/envs/steric_free_sim/lib/python3.7/pickle.py in save_tuple(self, obj)
#     770             for element in obj:
# --> 771                 save(element)
#     772             # Subtle.  Same as in the big comment below.
#
# ~/software/anaconda3/envs/steric_free_sim/lib/python3.7/pickle.py in save(self, obj, save_persistent_id)
#     503         if f is not None:
# --> 504             f(self, obj) # Call unbound method with explicit self
#     505             return
#
# ~/software/anaconda3/envs/steric_free_sim/lib/python3.7/site-packages/dill/_dill.py in save_function(pickler, obj)
#    1495                                 obj.__defaults__, obj.__closure__,
# -> 1496                                 obj.__dict__, fkwdefaults), obj=obj)
#    1497         else:
#
# ~/software/anaconda3/envs/steric_free_sim/lib/python3.7/pickle.py in save_reduce(self, func, args, state, listitems, dictitems, obj)
#     637             save(func)
# --> 638             save(args)
#     639             write(REDUCE)
#
# ~/software/anaconda3/envs/steric_free_sim/lib/python3.7/pickle.py in save(self, obj, save_persistent_id)
#     503         if f is not None:
# --> 504             f(self, obj) # Call unbound method with explicit self
#     505             return
#
# ~/software/anaconda3/envs/steric_free_sim/lib/python3.7/pickle.py in save_tuple(self, obj)
#     785         for element in obj:
# --> 786             save(element)
#     787
#
# ~/software/anaconda3/envs/steric_free_sim/lib/python3.7/pickle.py in save(self, obj, save_persistent_id)
#     503         if f is not None:
# --> 504             f(self, obj) # Call unbound method with explicit self
#     505             return
#
# ~/software/anaconda3/envs/steric_free_sim/lib/python3.7/pickle.py in save_tuple(self, obj)
#     770             for element in obj:
# --> 771                 save(element)
#     772             # Subtle.  Same as in the big comment below.
#
# ~/software/anaconda3/envs/steric_free_sim/lib/python3.7/pickle.py in save(self, obj, save_persistent_id)
#     503         if f is not None:
# --> 504             f(self, obj) # Call unbound method with explicit self
#     505             return
#
# ~/software/anaconda3/envs/steric_free_sim/lib/python3.7/site-packages/dill/_dill.py in save_cell(pickler, obj)
#    1226     f = obj.cell_contents
# -> 1227     pickler.save_reduce(_create_cell, (f,), obj=obj)
#    1228     log.info("# Ce")
#
# ~/software/anaconda3/envs/steric_free_sim/lib/python3.7/pickle.py in save_reduce(self, func, args, state, listitems, dictitems, obj)
#     637             save(func)
# --> 638             save(args)
#     639             write(REDUCE)
#
# ~/software/anaconda3/envs/steric_free_sim/lib/python3.7/pickle.py in save(self, obj, save_persistent_id)
#     503         if f is not None:
# --> 504             f(self, obj) # Call unbound method with explicit self
#     505             return
#
# ~/software/anaconda3/envs/steric_free_sim/lib/python3.7/pickle.py in save_tuple(self, obj)
#     770             for element in obj:
# --> 771                 save(element)
#     772             # Subtle.  Same as in the big comment below.
#
# ~/software/anaconda3/envs/steric_free_sim/lib/python3.7/pickle.py in save(self, obj, save_persistent_id)
#     503         if f is not None:
# --> 504             f(self, obj) # Call unbound method with explicit self
#     505             return
#
# ~/software/anaconda3/envs/steric_free_sim/lib/python3.7/site-packages/dill/_dill.py in save_instancemethod0(pickler, obj)
#    1175     if PY3:
# -> 1176         pickler.save_reduce(MethodType, (obj.__func__, obj.__self__), obj=obj)
#    1177     else:
#
# ~/software/anaconda3/envs/steric_free_sim/lib/python3.7/pickle.py in save_reduce(self, func, args, state, listitems, dictitems, obj)
#     637             save(func)
# --> 638             save(args)
#     639             write(REDUCE)
#
# ~/software/anaconda3/envs/steric_free_sim/lib/python3.7/pickle.py in save(self, obj, save_persistent_id)
#     503         if f is not None:
# --> 504             f(self, obj) # Call unbound method with explicit self
#     505             return
#
# ~/software/anaconda3/envs/steric_free_sim/lib/python3.7/pickle.py in save_tuple(self, obj)
#     770             for element in obj:
# --> 771                 save(element)
#     772             # Subtle.  Same as in the big comment below.
#
# ~/software/anaconda3/envs/steric_free_sim/lib/python3.7/pickle.py in save(self, obj, save_persistent_id)
#     548         # Save the reduce() output and finally memoize the object
# --> 549         self.save_reduce(obj=obj, *rv)
#     550
#
# ~/software/anaconda3/envs/steric_free_sim/lib/python3.7/pickle.py in save_reduce(self, func, args, state, listitems, dictitems, obj)
#     661         if state is not None:
# --> 662             save(state)
#     663             write(BUILD)
#
# ~/software/anaconda3/envs/steric_free_sim/lib/python3.7/pickle.py in save(self, obj, save_persistent_id)
#     503         if f is not None:
# --> 504             f(self, obj) # Call unbound method with explicit self
#     505             return
#
# ~/software/anaconda3/envs/steric_free_sim/lib/python3.7/site-packages/dill/_dill.py in save_module_dict(pickler, obj)
#     989             pickler._session = False
# --> 990         StockPickler.save_dict(pickler, obj)
#     991         log.info("# D2")
#
# ~/software/anaconda3/envs/steric_free_sim/lib/python3.7/pickle.py in save_dict(self, obj)
#     855         self.memoize(obj)
# --> 856         self._batch_setitems(obj.items())
#     857
#
# ~/software/anaconda3/envs/steric_free_sim/lib/python3.7/pickle.py in _batch_setitems(self, items)
#     881                     save(k)
# --> 882                     save(v)
#     883                 write(SETITEMS)
#
# ~/software/anaconda3/envs/steric_free_sim/lib/python3.7/pickle.py in save(self, obj, save_persistent_id)
#     523             if reduce is not None:
# --> 524                 rv = reduce(self.proto)
#     525             else:
#
# TypeError: can't pickle pyrosetta.rosetta.core.scoring.ScoreFunction objects
#
# During handling of the above exception, another exception occurred:
#
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-3-c5d299e1ff37> in <module>
# ----> 1 en = EnergyExplorer(rn, subunit_dir='../pdbs/snare_subunits/')
#       2 en.explore_network()
#
# ~/multi_assembly/multi_assembly/steric_free_simulator/energy_space_explorer.py in __init__(self, net, subunit_dir)
#      61                   "Continuing to process sequentially",
#      62                   sys.stderr)
# ---> 63             results = [self._pose_from_pdb(sunit) for sunit in subunit_files]
#      64
#      65         for i, res in enumerate(results):
#
# ~/multi_assembly/multi_assembly/steric_free_simulator/energy_space_explorer.py in <listcomp>(.0)
#      61                   "Continuing to process sequentially",
#      62                   sys.stderr)
# ---> 63             results = [self._pose_from_pdb(sunit) for sunit in subunit_files]
#      64
#      65         for i, res in enumerate(results):
#
# ~/multi_assembly/multi_assembly/steric_free_simulator/energy_space_explorer.py in _pose_from_pdb(self, pdb_file)
#      87             return self.written[name]
#      88         print("pdb_file: ", pdb_file)
# ---> 89         new_pose = pose_from_pdb(pdb_file)
#      90         self.relaxer.apply(new_pose)
#      91         new_pose.dump_pdb(os.path.join(os.path.split(pdb_file)[0], name + '.relaxed.clean.pdb'))
#
# ~/software/anaconda3/envs/steric_free_sim/lib/python3.7/site-packages/pyrosetta-2021.30+release.101ad938a08-py3.7-linux-x86_64.egg/pyrosetta/io/__init__.py in pose_from_pdb(filename)
#      18 # because otherwise, it wrecks a lot of people's scripts.  ~Labonte
#      19 def pose_from_pdb(filename):
# ---> 20     return pose_from_file(filename)
#      21
#      22
#
# RuntimeError:
#
# File: /home/benchmark/rosetta/source/src/core/io/pdb/pdb_reader.cc:79
# [ ERROR ] UtilityExitException
# ERROR: Assertion `! lines.empty()` failed.
